# %%
# !python --version
# Out:
# Python 3.7.12

# %%
# !pip install folium==0.2.1
# Out:
# ...
#      |████████████████████████████████| 69 kB 2.0 MB/s
# ...
#   Created wheel for folium: filename=folium-0.2.1-py3-none-any.whl size=79809 sha256=6382bb8c760bfc290e0c66770dad03129da675052ce323162b0da817f69c95cb
#   Stored in directory: /root/.cache/pip/wheels/9a/f0/3a/3f79a6914ff5affaf50cabad60c9f4d565283283c97f0bdccf
# Successfully built folium
# ...
#   Attempting uninstall: folium
#     Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# ...

# %%
# !pip install -q --pre poetry
# Out:
#      |████████████████████████████████| 190 kB 2.3 MB/s
#      |████████████████████████████████| 54 kB 2.1 MB/s
#      |████████████████████████████████| 421 kB 30.5 MB/s
#      |████████████████████████████████| 40 kB 5.3 MB/s
#      |████████████████████████████████| 7.2 MB 40.1 MB/s
#      |████████████████████████████████| 77 kB 6.3 MB/s
#      |████████████████████████████████| 54 kB 2.7 MB/s
#      |████████████████████████████████| 58 kB 5.4 MB/s
#      |████████████████████████████████| 58 kB 5.5 MB/s
#      |████████████████████████████████| 3.5 MB 39.2 MB/s
#      |████████████████████████████████| 496 kB 50.7 MB/s

# %%
# !poetry --version
# Out:
# Poetry (version 1.2.0a2)

# %%
#!git clone --branch luiza/ppo-representation https://github.com/luizapozzobon/ia368cc-project.git

# %%
# !git clone https://github.com/vwxyzjn/PPO-Implementation-Deep-Dive
# Out:
# Cloning into 'PPO-Implementation-Deep-Dive'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 81 (delta 47), reused 49 (delta 21), pack-reused 0
# Unpacking objects: 100% (81/81), done.

# %%
# %cd PPO-Implementation-Deep-Dive/
# Out:
# [Errno 2] No such file or directory: 'PPO-Implementation-Deep-Dive/'
# /content/PPO-Implementation-Deep-Dive

# %%
# !poetry install
# Out:
# Creating virtualenv ppo-implementation-deep-dive-ytwBj7O_-py3.7 in /root/.cache/pypoetry/virtualenvs
# Installing dependencies from lock file
# ...
#
# Package operations: 167 installs, 0 updates, 0 removals
#
#   • Installing attrs (21.2.0): Pending...
#   • Installing parso (0.8.2): Pending...
#   • Installing ptyprocess (0.7.0): Pending...
#   • Installing pycparser (2.20): Pending...
#   • Installing pyrsistent (0.18.0): Pending...
#   • Installing six (1.16.0): Pending...
#   • Installing ptyprocess (0.7.0): Downloading... 0%
#   • Installing pycparser (2.20): Pending...
#   • Installing pyrsistent (0.18.0): Pending...
#   • Installing six (1.16.0): Pending...
#   • Installing pycparser (2.20): Pending...
#   • Installing pyrsistent (0.18.0): Pending...
#   • Installing six (1.16.0): Pending...
#   • Installing ptyprocess (0.7.0): Downloading... 100%
#   • Installing pycparser (2.20): Pending...
#   • Installing pyrsistent (0.18.0): Pending...
# ...

# %%
# !poetry install -E atari
# Out:
# Installing dependencies from lock file
# ...
#
# Package operations: 4 installs, 0 updates, 0 removals
#
#   • Installing importlib-resources (5.2.2): Pending...
#   • Installing tqdm (4.62.2): Pending...
#   • Installing tqdm (4.62.2): Downloading... 0%
#   • Installing importlib-resources (5.2.2): Downloading... 0%
#   • Installing tqdm (4.62.2): Pending...
#   • Installing tqdm (4.62.2): Downloading... 0%
#   • Installing tqdm (4.62.2): Pending...
#   • Installing tqdm (4.62.2): Downloading... 0%
#   • Installing importlib-resources (5.2.2): Downloading... 100%
#   • Installing tqdm (4.62.2): Pending...
#   • Installing tqdm (4.62.2): Downloading... 0%
#   • Installing tqdm (4.62.2): Pending...
#   • Installing tqdm (4.62.2): Downloading... 0%
#   • Installing importlib-resources (5.2.2): Installing...
#   • Installing tqdm (4.62.2): Pending...
#   • Installing tqdm (4.62.2): Downloading... 0%
#   • Installing tqdm (4.62.2): Downloading... 100%
# ...

# %%
# !poetry run AutoROM
# Out:
# /root/.cache/pypoetry/virtualenvs/ppo-implementation-deep-dive-ytwBj7O_-py3.7/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/root/.cache/pypoetry/virtualenvs/ppo-implementation-deep-dive-ytwBj7O_-py3.7/lib/python3.7/site-packages/ale_py/roms
#
# Existing ROMs will be overwritten.
#
# I own a license to these Atari 2600 ROMs.
# I agree to not distribute these ROMs and wish to proceed: [Y/n]: y
# Installed /root/.cache/pypoetry/virtualenvs/ppo-implementation-deep-dive-ytwBj7O_-py3.7/lib/python3.7/site-packages/ale_py/roms/adventure.bin
# Installed /root/.cache/pypoetry/virtualenvs/ppo-implementation-deep-dive-ytwBj7O_-py3.7/lib/python3.7/site-packages/ale_py/roms/air_raid.bin
# ...

# %%
# !poetry add scikit-learn
# Out:
# Using version ^1.0.1 for scikit-learn
#
# Updating dependencies
# Resolving dependencies... (9.0s)PackageInfo: Invalid constraint (opencv-python (>=3.) ; extra == 'all') found in gym-0.21.0 dependencies, skipping
# <debug>PackageInfo:</debug> Invalid constraint (opencv-python (>=3.) ; extra == 'all') found in gym-0.21.0 dependencies, skipping
# PackageInfo: Invalid constraint (opencv-python (>=3.) ; extra == 'nomujoco') found in gym-0.21.0 dependencies, skipping
# <debug>PackageInfo:</debug> Invalid constraint (opencv-python (>=3.) ; extra == 'nomujoco') found in gym-0.21.0 dependencies, skipping
# PackageInfo: Invalid constraint (opencv-python (>=3.) ; extra == 'other') found in gym-0.21.0 dependencies, skipping
# <debug>PackageInfo:</debug> Invalid constraint (opencv-python (>=3.) ; extra == 'other') found in gym-0.21.0 dependencies, skipping
# ...

# %%
# !ls
# Out:
# categorization.py   ppo_atari.py	      probe.py		  README.md
# poetry.lock	    ppo_continuous_action.py  pyproject.toml	  utils.py
# ppo_atari_probe.py  ppo.py		      ram_annotations.py  wrapper.py

# %%
#%cd PPO-Implementation-Deep-Dive/
# Out:
# [Errno 2] No such file or directory: 'PPO-Implementation-Deep-Dive/'
# /content/PPO-Implementation-Deep-Dive

# %%
# !poetry run python ppo_atari_probe.py --track --capture-video
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# /content/PPO-Implementation-Deep-Dive/probe.py:188: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   label = torch.tensor(label_value).long().cpu()
# In our paper, we report F1 scores and accuracies averaged across each category.
#               That is, we take a mean across all state variables in a category to get the average score for that category.
#               Then we average all the category averages to get the final score that we report per game for each method.
#               These scores are called 'across_categories_avg_acc' and 'across_categories_avg_f1' respectively
#               We do this to prevent categories with large number of state variables dominating the mean F1 score.
#
# Epoch: Test
# 	 ball_x_acc:   0.0000
# 	 ball_y_acc:   0.0000
# ...
